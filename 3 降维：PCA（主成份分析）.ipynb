# %%
from sklearn import datasets as d

# %%
iris = d.load_iris()
iris_x = iris.data

# %%
# 导入分解模块
from sklearn import decomposition

# %%
pca = decomposition.PCA()
pca
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
iris_pca = pca.fit_transform(iris_x)
iris_pca[:5]
# Out:
# array([[ -2.68420713e+00,   3.26607315e-01,  -2.15118370e-02,
#           1.00615724e-03],
#        [ -2.71539062e+00,  -1.69556848e-01,  -2.03521425e-01,
#           9.96024240e-02],
#        [ -2.88981954e+00,  -1.37345610e-01,   2.47092410e-02,
#           1.93045428e-02],
#        [ -2.74643720e+00,  -3.11124316e-01,   3.76719753e-02,
#          -7.59552741e-02],
#        [ -2.72859298e+00,   3.33924564e-01,   9.62296998e-02,
#          -6.31287327e-02]])

# %%
# 查看降维的效果
pca.explained_variance_ratio_
# Out:
# array([ 0.92461621,  0.05301557,  0.01718514,  0.00518309])

# %%
# 用PCA将iris数据集转换成二维数据
pca = decomposition.PCA(n_components=2)
iris_x_prime = pca.fit_transform(iris_x)
iris_x_prime.shape
# Out:
# (150, 2)

# %%
from pyecharts import Scatter
import numpy as np
iris_y = iris.target
scatter = Scatter()
for label in np.unique(iris_y):
    scatter.add('',iris_x_prime[:,0][iris_y==label],iris_x_prime[:,1][iris_y==label])
scatter
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="7ca1089523be43de9514e8c71393484c" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('7ca1089523be43de9514e8c71393484c'));
# var option =  {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4644360,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     -2.6842071251039523,
#                     0.3266073147643889
#                 ],
#                 [
#                     -2.7153906156341345,
#                     -0.16955684755602668
#                 ],
#                 [
#                     -2.889819539617919,
#                     -0.13734560960502773
#                 ],
#                 [
#                     -2.7464371973087376,
#                     -0.3111243157519916
#                 ],
#                 [
#                     -2.7285929818313175,
#                     0.33392456356845424
#                 ],
#                 [
#                     -2.2798973610095996,
#                     0.7477827132251328
#                 ],
#                 [
#                     -2.8208906821806328,
#                     -0.08210451102468086
#                 ],
#                 [
#                     -2.6264819933238215,
#                     0.17040534896028947
#                 ],
#                 [
#                     -2.8879585653356377,
#                     -0.5707980263315914
#                 ],
#                 [
#                     -2.6738446867191237,
#                     -0.1066917037527387
#                 ],
#                 [
#                     -2.5065267893389054,
#                     0.6519350136725712
#                 ],
#                 [
#                     -2.613142718271059,
#                     0.021520631960257823
#                 ],
#                 [
#                     -2.7874339759971005,
#                     -0.22774018887110634
#                 ],
#                 [
#                     -3.2252004462749837,
#                     -0.5032799094854256
#                 ],
#                 [
#                     -2.643543216941148,
#                     1.1861948994134481
#                 ],
#                 [
#                     -2.3838693237993773,
#                     1.344754344559861
#                 ],
#                 [
#                     -2.622526203125811,
#                     0.8180896745965947
#                 ],
#                 [
#                     -2.648322732479129,
#                     0.3191366677508841
#                 ],
#                 [
#                     -2.199077961430765,
#                     0.8792440880917355
#                 ],
#                 [
#                     -2.5873461889177407,
#                     0.5204736388059674
#                 ],
#                 [
#                     -2.3105317013131357,
#                     0.39786782158889133
#                 ],
#                 [
#                     -2.543234907303698,
#                     0.44003175465981476
#                 ],
#                 [
#                     -3.2158576949001088,
#                     0.14161557162558344
#                 ],
#                 [
#                     -2.3031285376638846,
#                     0.10552267842998188
#                 ],
#                 [
#                     -2.356171086683901,
#                     -0.0312095890683384
#                 ],
#                 [
#                     -2.507917226837883,
#                     -0.1390563399131743
#                 ],
#                 [
#                     -2.4690559975451256,
#                     0.1378873145904174
#                 ],
#                 [
#                     -2.5623909468367527,
#                     0.3746845627501054
#                 ],
#                 [
#                     -2.6398212683765845,
#                     0.3192900659603213
#                 ],
#                 [
#                     -2.632847908030761,
#                     -0.19007583063362396
#                 ],
#                 [
#                     -2.5884620513033947,
#                     -0.19739307943769088
#                 ],
#                 [
#                     -2.410077337121598,
#                     0.4180800082476155
#                 ],
#                 [
#                     -2.647636673396903,
#                     0.8199826325595061
#                 ],
#                 [
#                     -2.5971594770759205,
#                     1.1000219280072672
#                 ],
#                 [
#                     -2.6738446867191237,
#                     -0.1066917037527387
#                 ],
#                 [
#                     -2.8669998469325373,
#                     0.07719309572358672
#                 ],
#                 [
#                     -2.625228464680424,
#                     0.6068000084215854
#                 ],
#                 [
#                     -2.6738446867191237,
#                     -0.1066917037527387
#                 ],
#                 [
#                     -2.9818426648539114,
#                     -0.48025004885607636
#                 ],
#                 [
#                     -2.5903230255856764,
#                     0.23605933728887238
#                 ],
#                 [
#                     -2.7701389107463275,
#                     0.2710594197651666
#                 ],
#                 [
#                     -2.8522110815663955,
#                     -0.932865367469544
#                 ],
#                 [
#                     -2.998296442832354,
#                     -0.334307574590777
#                 ],
#                 [
#                     -2.4055141012847043,
#                     0.19591725769606033
#                 ],
#                 [
#                     -2.208832954176708,
#                     0.4426960304210024
#                 ],
#                 [
#                     -2.7156651907474574,
#                     -0.24268148289811298
#                 ],
#                 [
#                     -2.5375733710135093,
#                     0.5103675454766053
#                 ],
#                 [
#                     -2.8403212968270117,
#                     -0.2205763382764766
#                 ],
#                 [
#                     -2.542685757077051,
#                     0.5862810253439877
#                 ],
#                 [
#                     -2.7039123148636532,
#                     0.1150108521705053
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "color": "#000",
#                         "fontSize": 12
#                     },
#                     "formatter": null
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "position": null,
#                     "textStyle": {
#                         "color": "#fff",

# %%
# 二维之后还是分离特征依然保留。我们可以查看这二维数据保留了多少变量信息：
pca.explained_variance_ratio_.sum()
# Out:
# 0.97763177502480336
