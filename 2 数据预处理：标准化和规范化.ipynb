# %% [markdown]
# ## 标准化（standardization）和规范化（normalization）

# %% [markdown]
# > 标准化：把数据调整（scaling）为标准正态分布（standard	normal）

# %% [markdown]
# 在回归问题和一些机器学习算法中，以及训练神经网络的过程中，通常需要对原始数据进行中心化（Zero-centered或者Mean-subtraction）处理和标准化（Standardization或Normalization）处理。
# * 目的：通过中心化和标准化处理，得到均值为0，标准差为1的服从标准正态分布的数据。
# 通过中心化得到均值为0的数据，再通过标准化得到标准差为1的数据
# $$x=	\frac	{x-	\bar	x}	\sigma$$

# %%
from sklearn import preprocessing #数据预处理模块
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
a = np.array([
    [10,2.7,3.6],
    [-100,5,-2],
    [120,20,40]
])

# %%
# 标准化和中心化，将数据集的均值变成0附近，标准差变成1
preprocessing.scale(a,axis=0),preprocessing.scale(a,axis=0).std(axis=0)
# Out:
# (array([[ 0.        , -0.85170713, -0.55138018],
#         [-1.22474487, -0.55187146, -0.852133  ],
#         [ 1.22474487,  1.40357859,  1.40351318]]), array([ 1.,  1.,  1.]))

# %% [markdown]
# > 规范化：目的？提升模型收敛速度和模型精度

# %%
# 规范化，norm可以指定正则类型
preprocessing.normalize(a,axis=0,norm='l2')
# Out:
# array([[ 0.06388766,  0.12986023,  0.08952676],
#        [-0.63887656,  0.24048191, -0.04973709],
#        [ 0.76665188,  0.96192763,  0.99474177]])

# %%
# 数据集分区，划分训练集和测试集
from sklearn.model_selection import train_test_split 
# 生成适合做classification数据集模块
from sklearn.datasets.samples_generator import make_classification
# svm模块
from sklearn.svm import SVC
import pyecharts as echarts

# %%
x, y = make_classification(
    n_samples=300, n_features=2,
    n_redundant=0, n_informative=2, 
    random_state=22, n_clusters_per_class=1, 
    scale=100)
scatter = echarts.Scatter()  
scatter.add('',x[y==0][:,0],x[y==0][:,1])
scatter.add('',x[y==1][:,0],x[y==1][:,1])
scatter
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="425dbf0297f743fba779f99c86c4ee54" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('425dbf0297f743fba779f99c86c4ee54'));
# var option =  {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 8321970,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     270.2916441571021,
#                     66.1960634069086
#                 ],
#                 [
#                     138.26196974878263,
#                     97.96444731094965
#                 ],
#                 [
#                     82.12034516810279,
#                     128.32430184658148
#                 ],
#                 [
#                     -67.04882051674159,
#                     175.78487793625692
#                 ],
#                 [
#                     -64.7279574641908,
#                     129.5404134988085
#                 ],
#                 [
#                     -16.074816630235446,
#                     144.84335711179938
#                 ],
#                 [
#                     176.2695529685811,
#                     100.17358037684099
#                 ],
#                 [
#                     256.33709853631166,
#                     66.23801273763338
#                 ],
#                 [
#                     75.28770725709049,
#                     129.25979853760077
#                 ],
#                 [
#                     151.91669858142288,
#                     103.67460831940912
#                 ],
#                 [
#                     184.96127685596602,
#                     83.11687714616738
#                 ],
#                 [
#                     123.36561792471042,
#                     94.29658511502885
#                 ],
#                 [
#                     153.52689278585487,
#                     84.61670539729744
#                 ],
#                 [
#                     227.0661309103514,
#                     50.61315001546212
#                 ],
#                 [
#                     37.40179425468219,
#                     95.30400134895898
#                 ],
#                 [
#                     -47.271679325201355,
#                     128.12673153297473
#                 ],
#                 [
#                     102.037852634345,
#                     96.75098981675654
#                 ],
#                 [
#                     221.33671107852223,
#                     50.386646713040804
#                 ],
#                 [
#                     55.93324362065204,
#                     170.40197245420893
#                 ],
#                 [
#                     92.53396186708494,
#                     104.21996857507116
#                 ],
#                 [
#                     82.00286310505972,
#                     118.75878056426698
#                 ],
#                 [
#                     -66.71369862120791,
#                     134.63671263649042
#                 ],
#                 [
#                     193.60875983993813,
#                     66.73858033748023
#                 ],
#                 [
#                     156.3973870022665,
#                     76.50791996114789
#                 ],
#                 [
#                     91.9363051669469,
#                     113.20561973585508
#                 ],
#                 [
#                     203.26137489369157,
#                     96.35647027051161
#                 ],
#                 [
#                     104.06324148672019,
#                     103.48209445746934
#                 ],
#                 [
#                     205.56763883832843,
#                     40.91773764568656
#                 ],
#                 [
#                     172.2780368892269,
#                     105.88483662255355
#                 ],
#                 [
#                     171.9731853146933,
#                     85.91233771095426
#                 ],
#                 [
#                     112.25492945604057,
#                     128.20547757683255
#                 ],
#                 [
#                     -18.142915047712215,
#                     154.04817695193628
#                 ],
#                 [
#                     -78.76483857444396,
#                     165.38538329854964
#                 ],
#                 [
#                     159.57306308719893,
#                     72.65563338686358
#                 ],
#                 [
#                     123.19930856162513,
#                     77.12444087850297
#                 ],
#                 [
#                     193.16579068534367,
#                     69.29678968527789
#                 ],
#                 [
#                     284.33093358413925,
#                     34.876486734603205
#                 ],
#                 [
#                     44.30972888641828,
#                     124.57957264864189
#                 ],
#                 [
#                     -85.20620389155891,
#                     129.9557599875312
#                 ],
#                 [
#                     4.261744332867545,
#                     111.72516332487501
#                 ],
#                 [
#                     211.24072529390637,
#                     87.14122427592702
#                 ],
#                 [
#                     279.91393645400103,
#                     43.34323839257955
#                 ],
#                 [
#                     116.47315070607766,
#                     115.767762050052
#                 ],
#                 [
#                     261.10035451518183,
#                     51.43296550503278
#                 ],
#                 [
#                     -79.83583397954106,
#                     189.97702877931317
#                 ],
#                 [
#                     -23.060444180883888,
#                     128.1382936875292
#                 ],
#                 [
#                     44.24103767074515,
#                     130.20903025426347
#                 ],
#                 [
#                     -108.18673683442609,
#                     113.72470214065315
#                 ],
#                 [
#                     -70.80408570226541,
#                     130.03599967902767
#                 ],
#                 [
#                     167.6524130647914,
#                     91.43018415976883
#                 ],
#                 [
#                     240.41227198212312,
#                     84.0749353300951
#                 ],
#                 [
#                     104.8219680272065,
#                     125.51044336713785
#                 ],
#                 [
#                     139.81309752826922,
#                     93.2454850793384
#                 ],
#                 [
#                     -36.898937397967615,
#                     140.12573669207032
#                 ],
#                 [
#                     162.3673279383281,
#                     77.4169770994532
#                 ],
#                 [
#                     200.55504981638364,

# %% [markdown]
# 数据标准化前模型准确率

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
svm_model = SVC()
svm_model.fit(x_train,y_train)
svm_model.score(x_test,y_test)
# Out:
# 0.52222222222222225

# %% [markdown]
# 数据标准化

# %%
x = preprocessing.scale(x)
scatter = echarts.Scatter()
scatter.add('',x[y==0][:,0],x[y==1][:,1])
scatter.add('',x[y==1][:,0],x[y==1][:,1])
scatter
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min'
#          }
#     });
# </script>
# <div id="fc63d25806b845bc999388cb8b035b67" style="width:800px; height:400px;"></div>
#
# <script>
#     require([ 'echarts' ],function(ec){
# 	var myChart = ec.init(document.getElementById('fc63d25806b845bc999388cb8b035b67'));
# var option =  {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 4069953,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": null,
#         "textStyle": {
#             "color": "#fff",
#             "fontSize": 14
#         }
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "name": "",
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     2.018670105351595,
#                     1.4587891861121238
#                 ],
#                 [
#                     1.0355391783613652,
#                     1.2908346497035652
#                 ],
#                 [
#                     0.6174924955675816,
#                     -2.2347722350804347
#                 ],
#                 [
#                     -0.4932640127349137,
#                     -2.9790660544133836
#                 ],
#                 [
#                     -0.47598219897223537,
#                     1.475667511325649
#                 ],
#                 [
#                     -0.11369691982245421,
#                     0.8605324227443516
#                 ],
#                 [
#                     1.3185545738850875,
#                     -0.8382208330701957
#                 ],
#                 [
#                     1.9147605453729282,
#                     2.2891850107335174
#                 ],
#                 [
#                     0.5666147086356248,
#                     1.650221271988921
#                 ],
#                 [
#                     1.13721621630904,
#                     1.3771418554795483
#                 ],
#                 [
#                     1.3832756496647716,
#                     -0.31978752084052664
#                 ],
#                 [
#                     0.9246166585323691,
#                     -0.4772382510377631
#                 ],
#                 [
#                     1.149206185442356,
#                     -0.11662772382633235
#                 ],
#                 [
#                     1.696800502185864,
#                     -1.6382859088755923
#                 ],
#                 [
#                     0.2845053045425865,
#                     0.33830444784172664
#                 ],
#                 [
#                     -0.34599773157508956,
#                     0.6934439726565067
#                 ],
#                 [
#                     0.7658039843777643,
#                     -0.9594154274485103
#                 ],
#                 [
#                     1.6541375943537784,
#                     -1.072711765918428
#                 ],
#                 [
#                     0.4224958061119098,
#                     -0.16427047613478865
#                 ],
#                 [
#                     0.6950352804337249,
#                     1.3482602474399523
#                 ],
#                 [
#                     0.6166176903386672,
#                     -1.1496336024358076
#                 ],
#                 [
#                     -0.4907685987206989,
#                     -0.9505502817563909
#                 ],
#                 [
#                     1.44766729495409,
#                     -0.9313996542347454
#                 ],
#                 [
#                     1.1705807109234476,
#                     -0.3076636163554928
#                 ],
#                 [
#                     0.6905849567601886,
#                     -2.0322868908555907
#                 ],
#                 [
#                     1.5195434427080263,
#                     -0.05785155081481638
#                 ],
#                 [
#                     0.7808856122684245,
#                     0.7242652915884381
#                 ],
#                 [
#                     1.5367165473145172,
#                     -1.0075080844621718
#                 ],
#                 [
#                     1.2888325972099361,
#                     1.010250971607612
#                 ],
#                 [
#                     1.286562584711543,
#                     2.4111235004228018
#                 ],
#                 [
#                     0.8418832767933413,
#                     -0.762109332562555
#                 ],
#                 [
#                     -0.12909657541800604,
#                     -0.6654443102389254
#                 ],
#                 [
#                     -0.5805048526848865,
#                     -0.35104159299982535
#                 ],
#                 [
#                     1.1942277083669526,
#                     -1.6057965706153274
#                 ],
#                 [
#                     0.9233782711847526,
#                     0.4849172290433119
#                 ],
#                 [
#                     1.4443688192323543,
#                     -0.024781523532429905
#                 ],
#                 [
#                     2.123210692083645,
#                     1.4819620735660521
#                 ],
#                 [
#                     0.33594377251216795,
#                     1.5435663703204547
#                 ],
#                 [
#                     -0.6284691113538369,
#                     -0.223144800762253
#                 ],
#                 [
#                     0.03773496184390651,
#                     -1.4462342025848736
#                 ],
#                 [
#                     1.5789599806257228,
#                     0.267711061533542
#                 ],
#                 [
#                     2.0903204611372574,
#                     0.8844841952070266
#                 ],
#                 [
#                     0.8732933653691375,
#                     0.8047140151669941
#                 ],
#                 [
#                     1.9502291192899999,
#                     0.5428154296811766
#                 ],
#                 [
#                     -0.5884797924863667,
#                     -1.0838442999450064
#                 ],
#                 [
#                     -0.16571391161051197,
#                     0.8564570536729063
#                 ],
#                 [
#                     0.33543227796487435,
#                     -0.9048969589213604
#                 ],
#                 [
#                     -0.7995887687800837,
#                     -0.4155865858797307
#                 ],
#                 [
#                     -0.5212267973095422,
#                     1.0186277245435011
#                 ],
#                 [
#                     1.2543888718973875,
#                     -0.20592762351059996
#                 ],
#                 [
#                     1.7961797069171797,
#                     0.8963039822293957
#                 ],
#                 [
#                     0.7865353082964062,
#                     0.8730607036350954
#                 ],
#                 [
#                     1.047089321907208,
#                     1.1445996684607118
#                 ],
#                 [
#                     -0.26875931201484904,
#                     1.6906592607992315
#                 ],
#                 [
#                     1.2150346080708099,
#                     -0.4

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
svm_model = SVC()
svm_model.fit(x_train,y_train)
svm_model.score(x_test,y_test)
# Out:
# 0.96666666666666667

# %% [markdown]
# ## 用阈值创建二元特征
# 当不需要将数据呈现为标准化分布时，可以直接使用或者通过二元特征来分割数据（特别是处理连续数据时）

# %%
from sklearn import datasets as d
boston = d.load_boston()
import numpy as np

# %% [markdown]
# 与标准化处理类似，scikit-learn有两种方法二元特征：
# * preprocessing.binarize	（一个函数）
# * preprocessing.Binarizer	（一个类）

# %%
from sklearn import preprocessing
new_target = preprocessing.binarize(boston.target,threshold=boston.target.mean())
new_target[0,:5]
# Out:
# array([ 1.,  0.,  1.,  1.,  1.])

# %% [markdown]
# 在sklearn中，要使用pipeline命令就要用Binarizer类

# %%
bin = preprocessing.Binarizer(boston.target.mean())
new_target = bin.fit_transform(boston.target)
new_target[0,:5]
# Out:
# array([ 1.,  0.,  1.,  1.,  1.])

# %% [markdown]
# ## 稀疏矩阵
# 稀疏矩阵的 	0	是不被存储的；这样可以节省很多空间。这就为 	binarizer	造成
# 了问题，需要指定阈值参数 	threshold	不小于 	0	来解决，如果 	threshold	小
# 于 	0	就会出现错误
